# %%
from sarpyx.snap.engine import GPT

def process_sar_data(product_path: str, outdir: str) -> None:
    """Process SAR data with default parameters.
    
    Args:
        product_path (str): Path to the SAR product (.SAFE directory)
        outdir (str): Output directory for processed data
    """
    tool = GPT(product=product_path, outdir=outdir, format='BEAM-DIMAP')
    tool.Calibration()
    tool.AdaptiveThresholding()
    tool.ObjectDiscrimination()
    print(f'Processing completed for {product_path}')

# Example usage
# process_sar_data('/path/to/your/sar/product.SAFE', '/path/to/output/directory')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sarpyx.snap.engine import GPT
#       3 def process_sar_data(product_path: str, outdir: str) -> None:
#       4     """Process SAR data with default parameters.
#       5
#       6     Args:
#       7         product_path (str): Path to the SAR product (.SAFE directory)
#       8         outdir (str): Output directory for processed data
#       9     """
#
# File /workspace/sarpyx/__init__.py:12
#       9 __author__ = 'ESA Phi-Lab'
#      11 # Import main components to make them available at package level
# ---> 12 from . import sla
#      13 from . import utils
#      14 from . import processor
#
# File /workspace/sarpyx/sla/__init__.py:8
#       1 """
#       2 Sub-Look Analysis (SLA) module for sarpyx.
#       3
#       4 This module provides functionality for analyzing sub-look data in SAR processing,
#       5 including handler utilities and analysis tools.
#       6 """
# ----> 8 from .core import SubLookAnalysis, Handler
#       9 # Import utility functions if they exist in utilis.py
#      10 # from .utilis import delete, unzip, delProd, command_line, iterNodes
#      12 __all__ = [
#      13     'SubLookAnalysis',
#      14     'Handler',
#    (...)
#      20     # 'iterNodes'
#      21 ]
#
# File /workspace/sarpyx/sla/core/__init__.py:6
#       1 """
#       2 Core components for the Sub-Look Analysis (SLA) module.
#       3 """
#       5 from .meta import Handler
# ----> 6 from .spectrum import SubLookAnalysis
#       8 __all__ = [
#       9     "Handler",
#      10     "SubLookAnalysis"
#      11 ]
#
# File /workspace/sarpyx/sla/core/spectrum.py:3
#       1 from pathlib import Path
#       2 import subprocess
# ----> 3 import lxml.etree as ET2
#       4 import pandas as pd
#       5 import os
#
# ModuleNotFoundError: No module named 'lxml'
