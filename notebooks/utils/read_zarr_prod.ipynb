# %%
from sarpyx.utils.zarr_utils import ProductHandler


pHandler = ProductHandler(file_path = '/Data_large/marine/PythonProjects/SAR/sarpyx/focused_data/tmp/processor_slice_1.zarr')

shapes = pHandler.array_shapes
H, W  = pHandler.array_shapes['raw']

row_start, row_end = 4000, 8000
col_start, col_end = 4000, 8000

pHandler.visualize_arrays(
    array_names=['raw','rc','az'], 
    rows=(row_start, row_end), 
    cols=(col_start, col_end),
    plot_type='magnitude',
    vminmax='auto',
)
