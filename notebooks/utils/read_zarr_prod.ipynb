# %%
from sarpyx.utils.zarr_utils import ProductHandler


handler = ProductHandler(
    file_path = '/Data_large/marine/PythonProjects/SAR/sarpyx/focused_data/s1a-s1-raw-s-hh-20160609t060632-20160609t060653-011630-011c9b_burst_0.zarr'
)

# %%
35000 // 1
# Out:
# 35000
