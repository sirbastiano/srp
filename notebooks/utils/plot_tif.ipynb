# %%
import rasterio
import matplotlib.pyplot as plt

# Read the .tif file
file_path = '/Data_large/marine/PythonProjects/SAR/sarpyx/notebooks/tmp3/S1A_IW_GRDH_1SDV_20250531T165718_20250531T165743_059441_0760E1_588E_OD.tif'  # Replace with your .tif file path
with rasterio.open(file_path) as src:
    tif_data = src.read(1)  # Read the first band
    profile = src.profile

# Plot the .tif file
plt.figure(figsize=(12, 12))
plt.imshow(tif_data[:], cmap='viridis', vmin=0, vmax=0.1)  # Adjust the slice as needed
plt.colorbar(label='Pixel Values')
plt.title('TIF File Visualization')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
