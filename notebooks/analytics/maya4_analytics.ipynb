# %%
import pandas as pd 

df = pd.read_csv('Maya4strip.csv')
# # drop duplicate Name
# df = df.drop_duplicates(subset=['Name'])
# df.to_csv('Maya4strip.csv', index=False)


PubblicationDate = df['PublicationDate'] # are like this '2023-05-30T13:31:20.580057Z'
GeoFootprint = df['GeoFootprint'] # are like this "{'type': 'Polygon', 'coordinates': [[[-95.3821, 28.8155], [-95.0186, 30.3602], [-95.8288, 30.4604], [-96.1797, 28.915], [-95.3821, 28.8155]]]}"
GeoFootprint[0]
# Out:
# "{'type': 'Polygon', 'coordinates': [[[-95.3821, 28.8155], [-95.0186, 30.3602], [-95.8288, 30.4604], [-96.1797, 28.915], [-95.3821, 28.8155]]]}"
