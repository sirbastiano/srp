# %%
from pathlib import Path

data_folder = '/Data_large/marine/PythonProjects/SAR/sarpyx/extracted_data'
zones = [x.stem for x in Path(data_folder).iterdir()]
print("Len of zones:", len(zones))
prods = [x for x in Path(data_folder).glob('**/*.SAFE') if x.is_dir()]
# Out:
# Len of zones: 44

# %%
len(prods)
# Out:
# 125
