# %%
import configparser
from phidown.search import CopernicusDataSearcher
import pandas as pd
import random

# %%
from phidown.search import CopernicusDataSearcher
import pandas as pd


# You can modify these parameters as needed
searcher = CopernicusDataSearcher()

# Configure the search parameters
searcher.query_by_filter(
    collection_name='SENTINEL-1',
    product_type=None,
    orbit_direction=None,
    cloud_cover_threshold=None,
    aoi_wkt=None,  # Example: aoi_wkt=aoi_wkt if you want to use the defined AOI
    start_date = '2018-05-03T00:00:00',
    end_date = '2025-05-03T04:00:00',
    top=1000,
    attributes={'processingLevel':'LEVEL0',
                'operationalMode': 'IW',    # IW, EW, WV
                # 'swathIdentifier': f'{swath}', # Swath identifier is: 1,2,3,4,5,6 for RAW
                } # Swath identifier Stripmap: S1, ..., S6 SLC| 'WV1,WV2' for wavemode
)

df = searcher.execute_query()
df
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  c9ac520c-81da-4025-baf7-ea36dcffae3b
# 1    application/octet-stream  32b2959c-eb99-4b12-898a-6e796e0c70c1
# 2    application/octet-stream  19c77fc4-bac9-4660-8f65-40429e16b870
# 3    application/octet-stream  f1a7097d-5fab-4770-adf0-5ba19a70b2b7
# 4    application/octet-stream  969be156-adb3-487f-bb48-434f81eee83a
# ..                        ...                                   ...
# 670  application/octet-stream  207d0515-903d-4283-a6c6-0d8d4b6f4273
# 671  application/octet-stream  39be3384-b72e-4f4d-97c5-a4ac59fd6436
# 672  application/octet-stream  ac66ad01-2a97-4a9d-ac07-23d326697879
# 673  application/octet-stream  938907b8-bcc3-4164-9f0d-214c9b1fa043
# 674  application/octet-stream  3ca02854-9b4b-4704-a045-14c54ddcbcd2
#
#                                                   Name  \
# 0    S1A_S6_RAW__0SDV_20250502T145324_20250502T1453...
# 1    S1A_S6_RAW__0SDV_20250502T082944_20250502T0830...
# 2    S1A_S6_RAW__0SDV_20250502T082919_20250502T0829...
# 3    S1A_S6_RAW__0SDV_20250502T082854_20250502T0829...
# 4    S1A_S6_RAW__0SDV_20250430T214429_20250430T2144...
# ..                                                 ...
# 670  S1B_S6_RAW__0SDV_20180507T064831_20180507T0648...
# 671  S1B_S6_RAW__0SDV_20180506T115412_20180506T1154...
# 672  S1A_S6_RAW__0SDV_20180503T082917_20180503T0829...
# 673  S1A_S6_RAW__0SDV_20180503T082852_20180503T0829...
# 674  S1A_S6_RAW__0SDV_20180503T082827_20180503T0828...
#
#                   ContentType  ContentLength                   OriginDate  \
# 0    application/octet-stream     1163825187  2025-05-02T15:34:14.793000Z
# 1    application/octet-stream     1502399321  2025-05-02T09:05:08.814000Z
# 2    application/octet-stream     1612509054  2025-05-02T09:05:16.139000Z
# 3    application/octet-stream     1533540097  2025-05-02T09:05:10.312000Z
# 4    application/octet-stream      676495220  2025-04-30T22:26:22.843000Z
# ..                        ...            ...                          ...
# 670  application/octet-stream     1171313600  2020-10-13T05:40:16.408000Z
# 671  application/octet-stream     1139858297  2020-10-13T07:00:46.153000Z
# 672  application/octet-stream     1387120635  2020-10-15T23:24:53.342000Z
# 673  application/octet-stream     1480546694  2020-10-15T18:56:16.532000Z
# 674  application/octet-stream     1481491158  2020-10-19T11:35:57.554000Z
#
# 0    geography'SRID=4326;POLYGON ((55.6298 -22.0188...
# 1    geography'SRID=4326;POLYGON ((145.2517 18.8476...
# 2    geography'SRID=4326;POLYGON ((145.5507 17.3357...
# 3    geography'SRID=4326;POLYGON ((145.8501 15.8238...
# 4    geography'SRID=4326;POLYGON ((-46.8796 -23.243...
# ..                                                 ...
# 670  geography'SRID=4326;POLYGON ((-176.7022 -44.91...
# 671  geography'SRID=4326;POLYGON ((-88.0184 40.7528...
# 672  geography'SRID=4326;POLYGON ((145.2523 18.8474...
# 673  geography'SRID=4326;POLYGON ((145.5512 17.3355...
# 674  geography'SRID=4326;POLYGON ((145.8508 15.8236...
#
#                                           GeoFootprint  \
# 0    {'type': 'Polygon', 'coordinates': [[[55.6298,...
# 1    {'type': 'Polygon', 'coordinates': [[[145.2517...
# 2    {'type': 'Polygon', 'coordinates': [[[145.5507...
# 3    {'type': 'Polygon', 'coordinates': [[[145.8501...
# 4    {'type': 'Polygon', 'coordinates': [[[-46.8796...
# ..                                                 ...
# 670  {'type': 'Polygon', 'coordinates': [[[-176.702...
# 671  {'type': 'Polygon', 'coordinates': [[[-88.0184...
# 672  {'type': 'Polygon', 'coordinates': [[[145.2523...
# 673  {'type': 'Polygon', 'coordinates': [[[145.5512...
# 674  {'type': 'Polygon', 'coordinates': [[[145.8508...
#
#                                             Attributes
# 0    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...
# ..                                                 ...
# 670  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 671  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 672  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 673  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 674  [{'@odata.type': '#OData.CSC.StringAttribute',...
#
# [675 rows x 16 columns]

# %% [markdown]
# # IW

# %%
from phidown.search import CopernicusDataSearcher
import pandas as pd


# You can modify these parameters as needed
searcher = CopernicusDataSearcher()


# Configure the search parameters
searcher._query_by_filter(
    collection_name='SENTINEL-1',
    product_type=None,
    orbit_direction=None,
    cloud_cover_threshold=None,
    aoi_wkt=None,  # Example: aoi_wkt=aoi_wkt if you want to use the defined AOI
    start_date = '2018-05-03T00:00:00',
    end_date = '2024-05-03T04:00:00',
    top=1000,
    attributes={'processingLevel':'LEVEL0',
                'operationalMode': 'IW',
                } # Swath identifier Stripmap: S1, ..., S6 SLC| 'WV1,WV2' for wavemode
    # base_url defaults to 'https://catalogue.dataspace.copernicus.eu/odata/v1/Products'
    # order_by defaults to 'ContentDate/Start desc'
)

df = searcher.execute_query()
df
# filename = df.iloc[0]['Name']  # Get the filename of the first product
# searcher.download_product(filename)
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  416b3a11-dc36-4da0-8f15-8f3da9293821
# 1    application/octet-stream  555e7dae-c194-4d53-b7ed-4c649094c256
# 2    application/octet-stream  98544461-2ea1-4879-8552-27ac1c95c89b
# 3    application/octet-stream  fc887546-f6ed-4b5d-ba26-528be0924edc
# 4    application/octet-stream  718bb6a4-4d92-46ec-836b-7ea1e2a7cfd9
# ..                        ...                                   ...
eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/03/S...
# 1    /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/03/S...
# 2    /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/03/S...
# 3    /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/03/S...
# 4    /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/03/S...
# ..                                                 ...
# 995  /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S...
# 996  /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S...
# 997  /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S...
# 998  /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S...
# 999  /eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S...
#
#                                               Checksum  \
# 0    [{'Value': 'b8e9d30b55a53ff740f9aab8f86744ba',...
# 1    [{'Value': 'dc9d54ca03df9fb3e50987185d97b0b5',...
# 2    [{'Value': '09cf1c176c929304c28d5c8598a515e5',...
# 3    [{'Value': 'a793de47fe93b1e2532b6eb87076b4b5',...
# 4    [{'Value': '3104db42b8aa9c0d80ccff73c9fcedb3',...
# ..                                                 ...
# 995  [{'Value': '55b817d16bdbca3d98df8dddcd326b76',...
# 996  [{'Value': 'f7e4feb80ce2e3c1f00ca2fff8243fa4',...
# 997  [{'Value': '181ebfeb9405f84a25d064dfbe54cb57',...
# 998  [{'Value': '24dc327979be49c8b8f76f88ba6d7399',...
# 999  [{'Value': 'b692f60c66dee7f21a30d1a1cfd8eefd',...
#
#                                            ContentDate  \
# 0    {'Start': '2024-05-03T03:19:26.175072Z', 'End'...
# 1    {'Start': '2024-05-03T03:19:01.174888Z', 'End'...
# 2    {'Start': '2024-05-03T03:18:36.174522Z', 'End'...
# 3    {'Start': '2024-05-03T03:18:11.174156Z', 'End'...
# 4    {'Start': '2024-05-03T03:17:46.173790Z', 'End'...
# ..                                                 ...
# 995  {'Start': '2024-05-01T11:36:09.885506Z', 'End'...
# 996  {'Start': '2024-05-01T11:05:37.068245Z', 'End'...
# 997  {'Start': '2024-05-01T11:05:12.067879Z', 'End'...
# 998  {'Start': '2024-05-01T11:04:47.067512Z', 'End'...
# 999  {'Start': '2024-05-01T11:04:22.067146Z', 'End'...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((32.5681 -26.9927...
# 1    geography'SRID=4326;POLYGON ((32.7208 -26.4569...
# 2    geography'SRID=4326;POLYGON ((33.1391 -24.9622...
# 3    geography'SRID=4326;POLYGON ((33.5475 -23.4659...
# 4    geography'SRID=4326;POLYGON ((33.9467 -21.9682...
# ..                                                 ...
# 995  geography'SRID=4326;POLYGON ((-84.1394 20.8775...
# 996  geography'SRID=4326;POLYGON ((100.0924 46.2888...
# 997  geography'SRID=4326;POLYGON ((100.5093 44.7857...
# 998  geography'SRID=4326;POLYGON ((100.9136 43.2816...
# 999  geography'SRID=4326;POLYGON ((101.3064 41.7766...
#
#                                           GeoFootprint  \
# 0    {'type': 'Polygon', 'coordinates': [[[32.5681,...
# 1    {'type': 'Polygon', 'coordinates': [[[32.7208,...
# 2    {'type': 'Polygon', 'coordinates': [[[33.1391,...
# 3    {'type': 'Polygon', 'coordinates': [[[33.5475,...
# 4    {'type': 'Polygon', 'coordinates': [[[33.9467,...
# ..                                                 ...
# 995  {'type': 'Polygon', 'coordinates': [[[-84.1394...
# 996  {'type': 'Polygon', 'coordinates': [[[100.0924...
# 997  {'type': 'Polygon', 'coordinates': [[[100.5093...
# 998  {'type': 'Polygon', 'coordinates': [[[100.9136...
# 999  {'type': 'Polygon', 'coordinates': [[[101.3064...
#
#                                             Attributes
# 0    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...
# ..                                                 ...
# 995  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 996  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 997  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 998  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 999  [{'@odata.type': '#OData.CSC.StringAttribute',...
#
# [1000 rows x 16 columns]

# %%
df.iloc[999]['S3Path']  # Get the filename of the first product
# Out:
# '/eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S1A_IW_RAW__0SDV_20240501T110422_20240501T110454_053677_0684F7_2A33.SAFE'

# %%
from phidown.s5cmd_utils import download 

download(
    s3_path=df.iloc[999]['S3Path'],  # Replace with the actual S3 path
    output_dir="/Data_large/marine/PythonProjects/SAR/sarpyx/decompressed_data"
)
# Out:
# INFO: Created configuration file: .s5cfg
# INFO: Downloading from: s3://eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S1A_IW_RAW__0SDV_20240501T110422_20240501T110454_053677_0684F7_2A33.SAFE/*
# INFO: Output directory: /Data_large/marine/PythonProjects/SAR/sarpyx/decompressed_data/S1A_IW_RAW__0SDV_20240501T110422_20240501T110454_053677_0684F7_2A33.SAFE
# INFO: Running command: s5cmd --endpoint-url https://eodata.dataspace.copernicus.eu cp s3://eodata/Sentinel-1/SAR/IW_RAW__0S/2024/05/01/S1A_IW_RAW__0SDV_20240501T110422_20240501T110454_053677_0684F7_2A33.SAFE/* /Data_large/marine/PythonProjects/SAR/sarpyx/decompressed_data/S1A_IW_RAW__0SDV_20240501T110422_20240501T110454_053677_0684F7_2A33.SAFE/
# True

# %%
from phidown.search import CopernicusDataSearcher
from phidown.s5cmd_utils import download 


searcher = CopernicusDataSearcher()
df = searcher.query_by_name(
    'S1A_S1_RAW__0SDV_20240629T123133_20240629T123159_054538_06A32D_8408.SAFE'
    )


download(
    s3_path=df.iloc[0]['S3Path']  # Get the S3 path of the product,
    output_dir="/Data_large/marine/PythonProjects/SAR/sarpyx/data/maya4ps"
)
# Out:
# INFO:phidown.s5cmd_utils:Downloading from: s3://eodata/Sentinel-1/SAR/S1_RAW__0S/2024/06/29/S1A_S1_RAW__0SDV_20240629T123133_20240629T123159_054538_06A32D_8408.SAFE/*
# INFO:phidown.s5cmd_utils:Output directory: /Data_large/marine/PythonProjects/SAR/sarpyx/data/maya4ps/S1A_S1_RAW__0SDV_20240629T123133_20240629T123159_054538_06A32D_8408.SAFE
# INFO:phidown.s5cmd_utils:Running command: s5cmd --endpoint-url https://eodata.dataspace.copernicus.eu cp s3://eodata/Sentinel-1/SAR/S1_RAW__0S/2024/06/29/S1A_S1_RAW__0SDV_20240629T123133_20240629T123159_054538_06A32D_8408.SAFE/* /Data_large/marine/PythonProjects/SAR/sarpyx/data/maya4ps/S1A_S1_RAW__0SDV_20240629T123133_20240629T123159_054538_06A32D_8408.SAFE/
# True
