# %%
from phidown.search import CopernicusDataSearcher
import pandas as pd


# You can modify these parameters as needed
searcher = CopernicusDataSearcher()

swath = 3

# Configure the search parameters
searcher._query_by_filter(
    collection_name='SENTINEL-1',
    product_type=None,
    orbit_direction=None,
    cloud_cover_threshold=None,
    aoi_wkt=None,  # Example: aoi_wkt=aoi_wkt if you want to use the defined AOI
    start_date = '2018-05-03T00:00:00',
    end_date = '2024-05-03T04:00:00',
    top=1000,
    attributes={'processingLevel':'LEVEL0',
                'operationalMode': 'SM',
                'swathIdentifier': f'{swath}', # Swath identifier is: 1,2,3,4,5,6 for RAW
                } # Swath identifier Stripmap: S1, ..., S6 SLC| 'WV1,WV2' for wavemode
    # base_url defaults to 'https://catalogue.dataspace.copernicus.eu/odata/v1/Products'
    # order_by defaults to 'ContentDate/Start desc'
)

df = searcher.execute_query()

# %%
df.iloc[:3]  # Display the first 3 results
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  3ef3d6d3-c183-49b9-9ff1-db7a648989a8
# 1  application/octet-stream  c69aa65a-a7de-420c-b010-8566c4fdc423
# 2  application/octet-stream  9fb49b5c-5eaa-412b-b7ce-f0c7f0b3145d
#
#                                                 Name  \
# 0  S1A_S3_RAW__0SDH_20240430T213606_20240430T2136...
# 1  S1A_S3_RAW__0SSH_20240428T000116_20240428T0001...
# 2  S1A_S3_RAW__0SDV_20240427T171940_20240427T1720...
#
#                 ContentType  ContentLength                   OriginDate  \
# 0  application/octet-stream     1458301922  2024-04-30T22:23:23.059000Z
# 1  application/octet-stream      548448080  2024-04-28T01:07:10.593000Z
# 2  application/octet-stream     1762748053  2024-04-27T18:04:04.620000Z
#
#                PublicationDate             ModificationDate  Online  \
# 0  2024-04-30T22:29:44.959925Z  2024-04-30T22:30:00.336858Z    True
# 1  2024-04-28T01:13:17.778942Z  2024-04-28T01:13:24.046514Z    True
# 2  2024-04-27T18:10:55.831833Z  2024-04-27T18:11:11.806105Z    True
#
#                   EvictionDate  \
# 0  9999-12-31T23:59:59.999999Z
# 1  9999-12-31T23:59:59.999999Z
# 2  9999-12-31T23:59:59.999999Z
#
#                                               S3Path  \
# 0  /eodata/Sentinel-1/SAR/S3_RAW__0S/2024/04/30/S...
# 1  /eodata/Sentinel-1/SAR/S3_RAW__0S/2024/04/28/S...
# 2  /eodata/Sentinel-1/SAR/S3_RAW__0S/2024/04/27/S...
#
#                                             Checksum  \
# 0  [{'Value': 'f40ad720c435479372eb82e8f7ffc324',...
# 1  [{'Value': '97ca1017d2ab34acbd89dbd90410497f',...
# 2  [{'Value': '31b3e28d9e43372c651c9032276b5e3f',...
#
#                                          ContentDate  \
# 0  {'Start': '2024-04-30T21:36:06.347282Z', 'End'...
# 1  {'Start': '2024-04-28T00:01:16.438713Z', 'End'...
# 2  {'Start': '2024-04-27T17:19:40.245293Z', 'End'...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((-46.5147 -24.603...
# 1  geography'SRID=4326;POLYGON ((73.1747 -53.9365...
# 2  geography'SRID=4326;POLYGON ((-178.276 -31.176...
#
#                                         GeoFootprint  \
# 0  {'type': 'Polygon', 'coordinates': [[[-46.5147...
# 1  {'type': 'Polygon', 'coordinates': [[[73.1747,...
# 2  {'type': 'Polygon', 'coordinates': [[[-178.276...
#
#                                           Attributes
# 0  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 1  [{'@odata.type': '#OData.CSC.StringAttribute',...
# 2  [{'@odata.type': '#OData.CSC.StringAttribute',...

# %%
filename = df.iloc[0]['Name']  # Get the filename of the first product
searcher.download_product(filename)
# Out:
# Access token saved to disk.
# Temporary S3 credentials created successfully.
# access: DIJD5B22JJLBVMIWK5DR
# secret: 7KrAXkRyfu7gfCR7YOUICCGHKtNQr9UZZZ4KoMgm
# S1A_S3_RAW__0SDH_20240430T213606_2024...|████████████████████| 100% 13.1k/13.1kB
# manifest.safe                           |████████████████████| 100% 17.4k/17.4kB
# s1a-s3-raw-s-hh-20240430t213606-20240...|████████████████████| 100% 1.27M/1.27MB
# s1a-s3-raw-s-hh-20240430t213606-20240...|████████████████████| 100% 1.80k/1.80kB
# s1a-s3-raw-s-hh-20240430t213606-20240...|████████████████████| 100% 746M/746MB
# s1a-s3-raw-s-hv-20240430t213606-20240...|████████████████████| 100% 1.27M/1.27MB
# s1a-s3-raw-s-hv-20240430t213606-20240...|████████████████████| 100% 1.80k/1.80kB
# s1a-s3-raw-s-hv-20240430t213606-20240...|████████████████████| 100% 710M/710MB
# s1-level-0-annot.xsd                    |████████████████████| 100% 8.07k/8.07kB
# s1-level-0-index.xsd                    |████████████████████| 100% 7.12k/7.12kB
# s1-level-0.xsd                          |████████████████████| 100% 23.0k/23.0kB
# Product download complete.
# Temporary S3 credentials deleted successfully.
