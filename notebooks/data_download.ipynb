# %%
from phidown.search import CopernicusDataSearcher
import pandas as pd


# You can modify these parameters as needed
searcher = CopernicusDataSearcher()

swath = 2
for swath in [4,5,6]:
    # Configure the search parameters
    searcher._query_by_filter(
        collection_name='SENTINEL-1',
        product_type=None,
        orbit_direction=None,
        cloud_cover_threshold=None,
        aoi_wkt=None,  # Example: aoi_wkt=aoi_wkt if you want to use the defined AOI
        start_date = '2018-05-03T00:00:00',
        end_date = '2024-05-03T04:00:00',
        top=1000,
        attributes={'processingLevel':'LEVEL0',
                    'operationalMode': 'SM',
                    'swathIdentifier': f'{swath}', # Swath identifier is: 1,2,3,4,5,6 for RAW
                    } # Swath identifier Stripmap: S1, ..., S6 SLC| 'WV1,WV2' for wavemode
        # base_url defaults to 'https://catalogue.dataspace.copernicus.eu/odata/v1/Products'
        # order_by defaults to 'ContentDate/Start desc'
    )

    df = searcher.execute_query()
    filename = df.iloc[0]['Name']  # Get the filename of the first product
    searcher.download_product(filename)
# Out:
# Access token saved to disk.
# Temporary S3 credentials created successfully.
# access: H6N6QGKPALGC71HFJ3QH
# secret: hwjVWKug0ZOaABKJ8Sw04V0iN3ssgOFEd8Qdsotu
# S1A_S4_RAW__0SDV_20240502T193657_2024...|████████████████████| 100% 13.1k/13.1kB
# manifest.safe                           |████████████████████| 100% 17.4k/17.4kB
# s1a-s4-raw-s-vh-20240502t193657-20240...|████████████████████| 100% 1.31M/1.31MB
# s1a-s4-raw-s-vh-20240502t193657-20240...|████████████████████| 100% 1.87k/1.87kB
# s1a-s4-raw-s-vh-20240502t193657-20240...|████████████████████| 100% 747M/747MB
# s1a-s4-raw-s-vv-20240502t193657-20240...|████████████████████| 100% 1.31M/1.31MB
# s1a-s4-raw-s-vv-20240502t193657-20240...|████████████████████| 100% 1.87k/1.87kB
# s1a-s4-raw-s-vv-20240502t193657-20240...|████████████████████| 100% 695M/695MB
# s1-level-0-annot.xsd                    |████████████████████| 100% 8.07k/8.07kB
# s1-level-0-index.xsd                    |████████████████████| 100% 7.12k/7.12kB
# s1-level-0.xsd                          |████████████████████| 100% 23.0k/23.0kB
# Product download complete.
# Temporary S3 credentials deleted successfully.
# Using cached access token.
# Access token: eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJYVUh3VWZKaHVDVWo0X3k4ZF8xM0hxWXBYMFdwdDd2anhob2FPLUxzREZFIn0.....VX2r2-8crcFq8czEJCq6GqiEUzBNgp24R6ijfKtHgkVdhaDwCeHK6_WOvEETM-zhJZNyc5JRpdQOZ4lgW_4DuhMAzLqKcOt5rT0sJ2humUFw_I3DfnkmmoB4GPl8YUbMziLWvYe_4etgPhc0vBkc77ycDgW-cW8GoKraTPHMsuQeuhC-AKlBlK9IFZO1bQpvrieR4jkj_tE_0B6krB7f71lzAvKC9xTxFYgJ6loQuOLwr0UUkbMDATL48exB0F5VsyqzBYdsad4TvJlA05dPzX-qPRv7WfSv89pML34dEBS9AjewYmDA9ZU7SuzMkJBbCidLDku3KKOm_6FqVCwiWA
# Temporary S3 credentials created successfully.
# access: J16XTG6853CU7AUSKHIP
# secret: XaIdRFg9Vd4LijSWMib3uknsIJ6eOEStxIDvGz5v
# S1A_S5_RAW__0SDV_20240429T200803_2024...|████████████████████| 100% 13.1k/13.1kB
# manifest.safe                           |████████████████████| 100% 17.4k/17.4kB
# s1a-s5-raw-s-vh-20240429t200803-20240...|████████████████████| 100% 1.51M/1.51MB
# s1a-s5-raw-s-vh-20240429t200803-20240...|████████████████████| 100% 2.12k/2.12kB
# s1a-s5-raw-s-vh-20240429t200803-20240...|████████████████████| 100% 841M/841MB
# s1a-s5-raw-s-vv-20240429t200803-20240...|████████████████████| 100% 1.51M/1.51MB
# s1a-s5-raw-s-vv-20240429t200803-20240...|████████████████████| 100% 2.12k/2.12kB
# s1a-s5-raw-s-vv-20240429t200803-20240...|████████████████████| 100% 785M/785MB
# s1-level-0-annot.xsd                    |████████████████████| 100% 8.07k/8.07kB
# s1-level-0-index.xsd                    |████████████████████| 100% 7.12k/7.12kB
# s1-level-0.xsd                          |████████████████████| 100% 23.0k/23.0kB
# Product download complete.
# Failed to delete temporary S3 credentials. Status code: 403
# Access token saved to disk.
# Temporary S3 credentials created successfully.
# access: 0ULF003TLREVWZY52GCA
# secret: RYLOEnT4ruewY6QgvQCQVlLXtXgqleBdaJDegXm1
# S1A_S6_RAW__0SDV_20240502T195132_2024...|████████████████████| 100% 13.1k/13.1kB
# manifest.safe                           |████████████████████| 100% 17.4k/17.4kB
# s1a-s6-raw-s-vh-20240502t195132-20240...|████████████████████| 100% 886k/886kB
# s1a-s6-raw-s-vh-20240502t195132-20240...|████████████████████| 100% 1.30k/1.30kB
# s1a-s6-raw-s-vh-20240502t195132-20240...|████████████████████| 100% 480M/480MB
# s1a-s6-raw-s-vv-20240502t195132-20240...|████████████████████| 100% 886k/886kB
# s1a-s6-raw-s-vv-20240502t195132-20240...|████████████████████| 100% 1.30k/1.30kB
# s1a-s6-raw-s-vv-20240502t195132-20240...|████████████████████| 100% 450M/450MB
# s1-level-0-annot.xsd                    |████████████████████| 100% 8.07k/8.07kB
# s1-level-0-index.xsd                    |████████████████████| 100% 7.12k/7.12kB
# s1-level-0.xsd                          |████████████████████| 100% 23.0k/23.0kB
# Product download complete.
# Temporary S3 credentials deleted successfully.
