# %%
# from datetime import datetime, timedelta

# def get_time_window(dt_str, seconds=5):
#     """
#     Convert a datetime string into ISO-like format with offsets before and after.

#     This function takes an input datetime string in the format
#     'YYYY-MM-DD HH:MM:SS' (with a space separator), converts it to
#     'YYYY-MM-DDTHH:MM:SS' (with a 'T' separator), and returns two strings:
#     one representing the time `seconds` before, and another representing
#     the time `seconds` after the given datetime.

#     Parameters
#     ----------
#     dt_str : str
#         A datetime string in the format 'YYYY-MM-DD HH:MM:SS'.
#     seconds : int, optional
#         The number of seconds to offset before and after the given time.
#         Default is 5.

#     Returns
#     -------
#     tuple of str
#         A tuple containing two datetime strings in the format
#         'YYYY-MM-DDTHH:MM:SS':
#         - The first string is the input time minus `seconds`.
#         - The second string is the input time plus `seconds`.

#     Examples
#     --------
#     >>> get_time_window('2020-10-06 11:35:23', seconds=5)
#     ('2020-10-06T11:35:18', '2020-10-06T11:35:28')
#     """
#     # Parse input datetime
#     dt = datetime.strptime(dt_str, "%Y-%m-%d %H:%M:%S")
    
#     # Compute before and after times
#     before = dt - timedelta(seconds=seconds)
#     after = dt + timedelta(seconds=seconds)
    
#     # Return formatted strings
#     return before.strftime("%Y-%m-%dT%H:%M:%S"), after.strftime("%Y-%m-%dT%H:%M:%S")


# # Example usage
# print(get_time_window('2020-10-06 11:35:23', seconds=5))
# # -> ('2020-10-06T11:35:18', '2020-10-06T11:35:28')
# geojson_to_wkt(GeoFootprint) #
# {'type': 'MultiPolygon',
#  'coordinates': [[[[-6.108396, 46.729179],
#     [-5.665298, 48.22562],
#     [-9.178612, 48.633568],
#     [-9.522814, 47.136372],
#     [-6.108396, 46.729179]]]]}

#  = df_exact.iloc[0]['OriginDate']
# start, stop = get_time_indow(OriginDate, seconds=15)
# print(f'Start: {start}, Stop: {stop}')  w

# %%
import configparser
from phidown.search import CopernicusDataSearcher
import time

import pandas as pd
import random
from pathlib import Path

GRD_products = [x for x in Path('/Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD').iterdir() if x.is_dir()]
print(f'Found {len(GRD_products)} L1 products')
# Out:
# Found 754 L1 products

# %%
def geojson_to_polygon_wkt(geometry, *, on_multipolygon="first"):
    """
    Convert a GeoJSON geometry to a POLYGON WKT string.

    This function guarantees a POLYGON WKT output. Behavior by geometry type:
    - Polygon: serialized directly to POLYGON (2D or Z).
    - MultiPolygon: by default takes the first polygon and returns it as POLYGON.
      You can control this with `on_multipolygon`.
    - Any other geometry type: raises ValueError.

    Parameters
    ----------
    geometry : dict
        A GeoJSON-like geometry dictionary with keys:
        - 'type' (str): One of {'Polygon','MultiPolygon'} is supported; others raise.
        - 'coordinates' (list): For 'Polygon', a list of linear rings; for 'MultiPolygon',
          a list of polygons (each a list of rings). Rings are expected in GeoJSON order
          [x, y] or [x, y, z]. Rings should be closed (first == last); this function
          does not enforce closure.
    on_multipolygon : {'first', 'error'}, optional
        Behavior when input is a MultiPolygon:
        - 'first' (default): Use the first polygon within the MultiPolygon.
        - 'error': Raise ValueError if there is more than one polygon.
        Note: True topological merging (dissolve/union) is not performed.

    Returns
    -------
    str
        A POLYGON (or 'POLYGON Z') WKT string.

    Raises
    ------
    ValueError
        If geometry type is unsupported, structure is invalid, or MultiPolygon handling
        is set to 'error' with multiple polygons.

    Notes
    -----
    - This function does not perform geometric operations (e.g., union/merge).
    - Presence of any Z value in the chosen polygon promotes output to 'POLYGON Z'.
    """

    def _is_3d_coords(obj):
        """Return True if any coordinate has 3 elements."""
        found = False

        def _walk(o):
            nonlocal found
            if found:
                return
            if isinstance(o, (list, tuple)):
                if o and all(isinstance(v, (int, float)) for v in o):
                    if len(o) >= 3:
                        found = True
                else:
                    for item in o:
                        _walk(item)

        _walk(obj)
        return found

    def _fmt_num(n):
        """Format numbers compactly, removing trailing zeros and unnecessary decimals."""
        if isinstance(n, int):
            return str(n)
        return f"{float(n):.15g}"

    def _fmt_coord(coord):
        return " ".join(_fmt_num(c) for c in coord[:3])  # x y or x y z

    def _fmt_ring(ring):
        return f"({_fmt_coord_list(ring)})"

    def _fmt_coord_list(coords):
        return ", ".join(_fmt_coord(c) for c in coords)

    gtype = geometry.get("type")
    if not gtype:
        raise ValueError("Geometry missing 'type'")

    if gtype == "Polygon":
        rings = geometry.get("coordinates")
        if not isinstance(rings, list):
            raise ValueError("Polygon 'coordinates' must be a list of rings")
        dim = " Z" if _is_3d_coords(rings) else ""
        return f"POLYGON{dim} ({', '.join(_fmt_ring(r) for r in rings)})"

    if gtype == "MultiPolygon":
        polys = geometry.get("coordinates")
        if not isinstance(polys, list) or not polys:
            raise ValueError("MultiPolygon 'coordinates' must be a non-empty list of polygons")
        if on_multipolygon == "error" and len(polys) != 1:
            raise ValueError("MultiPolygon has multiple polygons; set on_multipolygon='first' to pick the first")
        chosen = polys[0]
        if not isinstance(chosen, list):
            raise ValueError("Invalid MultiPolygon structure: expected list of polygons (list of rings)")
        dim = " Z" if _is_3d_coords(chosen) else ""
        return f"POLYGON{dim} ({', '.join(_fmt_ring(r) for r in chosen)})"

    raise ValueError(f"Unsupported geometry type for polygon output: {gtype}")




def get_corresponding_slc(geo_footprint: dict, start: str, end: str) -> str:
    """
    Retrieve the corresponding SLC product name for a given GeoFootprint and time window.

    Args:
        geo_footprint (dict): GeoJSON-like geometry dictionary.
        start (str): Start time in ISO 8601 format.
        end (str): End time in ISO 8601 format.

    Returns:
        str: Name of the corresponding SLC product.
    """
    searcher = CopernicusDataSearcher()
    searcher.query_by_filter(
        collection_name='SENTINEL-1',
        product_type='SLC',
        orbit_direction=None,
        cloud_cover_threshold=None,
        aoi_wkt=geojson_to_polygon_wkt(geo_footprint),
        start_date=start,
        end_date=end,
        top=1000,
        attributes={'processingLevel': 'LEVEL1'}
    )
    df = searcher.execute_query()
    product_name = df.sample(n=1)['Name'].values[0]
    return product_name


def get_corresponding_raw(geo_footprint: dict, start: str, end: str) -> str:
    """
    Retrieve the corresponding L0 product name for a given GeoFootprint and time window.

    Args:
        geo_footprint (dict): GeoJSON-like geometry dictionary.
        start (str): Start time in ISO 8601 format.
        end (str): End time in ISO 8601 format.

    Returns:
        str: Name of the corresponding L0 product.
    """
    searcher = CopernicusDataSearcher()
    searcher.query_by_filter(
        collection_name='SENTINEL-1',
        product_type=None,
        orbit_direction=None,
        cloud_cover_threshold=None,
        aoi_wkt=geojson_to_polygon_wkt(geo_footprint),
        start_date=start,
        end_date=end,
        top=1000,
        attributes={'processingLevel': 'LEVEL0'}
    )
    df = searcher.execute_query()
    product_name = df.sample(n=1)['Name'].values[0]
    return product_name
# Out:
# POLYGON ((-6.108396 46.729179, -5.665298 48.22562, -9.178612 48.633568, -9.522814 47.136372, -6.108396 46.729179))

# %%
data_collector = []


for idx, product in enumerate(GRD_products):
    print(f'Using product: {product}')

    # =========== A) GRD info extraction ====================
    try:
        product_name = product.name
        print(f'Product name: {product_name}')

        # find info about the prod 

        searcher_by_name = CopernicusDataSearcher()

        # Replace with an actual product name you want to find
        product_to_find = product_name # Example, replace with a recent, valid name

        print(f"Searching for product with exact name: {product_to_find}\n")
        df_exact = searcher_by_name.query_by_name(product_name=product_to_find)

        if not df_exact.empty:
            searcher_by_name.display_results(top_n=1)
            # display(df_exact)
        else:
            print(f"Product '{product_to_find}' not found or an error occurred.")
            
            
        GeoFootprint = df_exact.iloc[0]['GeoFootprint']
        ContentDate = df_exact.iloc[0]['ContentDate']

        start = ContentDate['Start']
        end = ContentDate['End']
        # ========================= End Extract product info =========================
    
    except Exception as e:
        print(f"Error extracting product info: {e}")
        print(f"Exception occurred for product: {product}")
        continue


    try:
        # =========== B) Find corresponding products ====================
        RAW_product_name = get_corresponding_raw(GeoFootprint, start, end)
        # print(f'Found corresponding L0 product: {L0_product_name}')
        SLC_product_name = get_corresponding_slc(GeoFootprint, start, end)
        # print(f'Found corresponding SLC product: {SLC_product_name}')
        
        data_collector.append({
            'GRD': product_name,
            'SLC': SLC_product_name,
            'L0': RAW_product_name
        })        
        # save as pkl after each append
        pd.to_pickle(data_collector, 'xview3_multi.pkl')
        time.sleep(random.uniform(1, 3))  # Sleep between 1 to 3 seconds to avoid overwhelming the server
        
    except Exception as e:
        print(f"Error finding corresponding L0 product: {e}")
        continue
# Out:
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201006T064054_20201006T064119_034672_0409DA_8975.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201006T064054_20201006T064119_034672_0409DA_8975.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201006T064054_20201006T064119_034672_0409DA_8975.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201105T183650_20201105T183715_035117_041924_224E.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201105T183650_20201105T183715_035117_041924_224E.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201105T183650_20201105T183715_035117_041924_224E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201002T062014_20201002T062039_023630_02CE51_552C.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201002T062014_20201002T062039_023630_02CE51_552C.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201002T062014_20201002T062039_023630_02CE51_552C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200402T065009_20200402T065034_031945_03B052_104C.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200402T065009_20200402T065034_031945_03B052_104C.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200402T065009_20200402T065034_031945_03B052_104C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201112T182823_20201112T182848_035219_041CBB_9649.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201112T182823_20201112T182848_035219_041CBB_9649.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201112T182823_20201112T182848_035219_041CBB_9649.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200509T165819_20200509T165844_032491_03C341_6486.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200509T165819_20200509T165844_032491_03C341_6486.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200509T165819_20200509T165844_032491_03C341_6486.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200117T063137_20200117T063202_019853_0258AC_22AE.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200117T063137_20200117T063202_019853_0258AC_22AE.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200117T063137_20200117T063202_019853_0258AC_22AE.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200205T182103_20200205T182138_031121_0393A6_5905.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200205T182103_20200205T182138_031121_0393A6_5905.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200205T182103_20200205T182138_031121_0393A6_5905.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201111T064028_20201111T064053_035197_041C0C_3563.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201111T064028_20201111T064053_035197_041C0C_3563.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201111T064028_20201111T064053_035197_041C0C_3563.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201111T051421_20201111T051446_035196_041C02_3C0A.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201111T051421_20201111T051446_035196_041C02_3C0A.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201111T051421_20201111T051446_035196_041C02_3C0A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201118T182800_20201118T182825_024323_02E3F9_0DC6.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201118T182800_20201118T182825_024323_02E3F9_0DC6.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201118T182800_20201118T182825_024323_02E3F9_0DC6.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200907T050726_20200907T050751_034248_03FAD3_34CA.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200907T050726_20200907T050751_034248_03FAD3_34CA.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200907T050726_20200907T050751_034248_03FAD3_34CA.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200328T165734_20200328T165759_020895_0279FF_C9CB.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200328T165734_20200328T165759_020895_0279FF_C9CB.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200328T165734_20200328T165759_020895_0279FF_C9CB.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200722T075746_20200722T075811_022581_02ADB5_0BBB.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200722T075746_20200722T075811_022581_02ADB5_0BBB.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200722T075746_20200722T075811_022581_02ADB5_0BBB.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200626T165822_20200626T165847_033191_03D84E_AF01.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200626T165822_20200626T165847_033191_03D84E_AF01.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200626T165822_20200626T165847_033191_03D84E_AF01.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201112T182848_20201112T182913_035219_041CBB_4402.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201112T182848_20201112T182913_035219_041CBB_4402.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201112T182848_20201112T182913_035219_041CBB_4402.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201129T064110_20201129T064135_024476_02E8CA_FDB8.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201129T064110_20201129T064135_024476_02E8CA_FDB8.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201129T064110_20201129T064135_024476_02E8CA_FDB8.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200121T170912_20200121T170937_019918_025ACD_5D3C.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200121T170912_20200121T170937_019918_025ACD_5D3C.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200121T170912_20200121T170937_019918_025ACD_5D3C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200116T054746_20200116T054811_019838_02582D_5A20.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200116T054746_20200116T054811_019838_02582D_5A20.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200116T054746_20200116T054811_019838_02582D_5A20.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200426T051115_20200426T051140_032294_03BC92_6AC3.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200426T051115_20200426T051140_032294_03BC92_6AC3.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200426T051115_20200426T051140_032294_03BC92_6AC3.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200204T182751_20200204T182816_020123_02616B_40F5.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200204T182751_20200204T182816_020123_02616B_40F5.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200204T182751_20200204T182816_020123_02616B_40F5.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200730T180445_20200730T180509_022704_02B17A_1C80.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200730T180445_20200730T180509_022704_02B17A_1C80.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200730T180445_20200730T180509_022704_02B17A_1C80.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200513T052958_20200513T053027_032542_03C4E2_DAEA.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200513T052958_20200513T053027_032542_03C4E2_DAEA.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200513T052958_20200513T053027_032542_03C4E2_DAEA.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200625T065013_20200625T065038_033170_03D7B6_C6B3.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200625T065013_20200625T065038_033170_03D7B6_C6B3.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200625T065013_20200625T065038_033170_03D7B6_C6B3.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200223T062445_20200223T062510_031376_039C79_0284.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200223T062445_20200223T062510_031376_039C79_0284.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200223T062445_20200223T062510_031376_039C79_0284.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200919T182800_20200919T182825_023448_02C8A5_9804.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200919T182800_20200919T182825_023448_02C8A5_9804.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200919T182800_20200919T182825_023448_02C8A5_9804.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201010T185940_20201010T190013_034738_040C14_514E.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201010T185940_20201010T190013_034738_040C14_514E.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201010T185940_20201010T190013_034738_040C14_514E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200116T165735_20200116T165800_019845_025868_DDA5.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200116T165735_20200116T165800_019845_025868_DDA5.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200116T165735_20200116T165800_019845_025868_DDA5.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200723T181139_20200723T181204_022602_02AE58_D4B6.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200723T181139_20200723T181204_022602_02AE58_D4B6.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200723T181139_20200723T181204_022602_02AE58_D4B6.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200429T062441_20200429T062506_021355_02888B_587F.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200429T062441_20200429T062506_021355_02888B_587F.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200429T062441_20200429T062506_021355_02888B_587F.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200316T054745_20200316T054810_020713_027441_4612.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200316T054745_20200316T054810_020713_027441_4612.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200316T054745_20200316T054810_020713_027441_4612.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200810T181211_20200810T181236_033848_03ECC0_C350.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200810T181211_20200810T181236_033848_03ECC0_C350.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200810T181211_20200810T181236_033848_03ECC0_C350.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201104T051124_20201104T051149_035094_041869_D721.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201104T051124_20201104T051149_035094_041869_D721.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201104T051124_20201104T051149_035094_041869_D721.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200226T052146_20200226T052215_031419_039DEC_689A.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200226T052146_20200226T052215_031419_039DEC_689A.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200226T052146_20200226T052215_031419_039DEC_689A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200623T181208_20200623T181233_033148_03D710_7725.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200623T181208_20200623T181233_033148_03D710_7725.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200623T181208_20200623T181233_033148_03D710_7725.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200609T182842_20200609T182907_032944_03D0E0_B05A.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200609T182842_20200609T182907_032944_03D0E0_B05A.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200609T182842_20200609T182907_032944_03D0E0_B05A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201007T182823_20201007T182848_034694_040A85_C243.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201007T182823_20201007T182848_034694_040A85_C243.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201007T182823_20201007T182848_034694_040A85_C243.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200820T182846_20200820T182911_033994_03F1E8_79C9.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200820T182846_20200820T182911_033994_03F1E8_79C9.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200820T182846_20200820T182911_033994_03F1E8_79C9.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200821T164040_20200821T164105_023024_02BB71_8707.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200821T164040_20200821T164105_023024_02BB71_8707.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200821T164040_20200821T164105_023024_02BB71_8707.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200229T062259_20200229T062324_020480_026CDE_D9EE.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200229T062259_20200229T062324_020480_026CDE_D9EE.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200229T062259_20200229T062324_020480_026CDE_D9EE.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201013T182801_20201013T182826_023798_02D392_686D.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201013T182801_20201013T182826_023798_02D392_686D.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201013T182801_20201013T182826_023798_02D392_686D.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200508T174433_20200508T174458_032477_03C2D4_D88F.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200508T174433_20200508T174458_032477_03C2D4_D88F.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200508T174433_20200508T174458_032477_03C2D4_D88F.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201001T054009_20201001T054034_023615_02CDE1_B68E.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201001T054009_20201001T054034_023615_02CDE1_B68E.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201001T054009_20201001T054034_023615_02CDE1_B68E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200510T054002_20200510T054027_021515_028D99_201C.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200510T054002_20200510T054027_021515_028D99_201C.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200510T054002_20200510T054027_021515_028D99_201C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200905T174440_20200905T174505_034227_03FA22_7468.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200905T174440_20200905T174505_034227_03FA22_7468.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200905T174440_20200905T174505_034227_03FA22_7468.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200319T061628_20200319T061653_020757_0275BA_68B9.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200319T061628_20200319T061653_020757_0275BA_68B9.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200319T061628_20200319T061653_020757_0275BA_68B9.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200402T170912_20200402T170937_020968_027C5A_D1AB.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200402T170912_20200402T170937_020968_027C5A_D1AB.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200402T170912_20200402T170937_020968_027C5A_D1AB.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200417T182104_20200417T182139_032171_03B84C_26D4.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200417T182104_20200417T182139_032171_03B84C_26D4.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200417T182104_20200417T182139_032171_03B84C_26D4.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201031T063211_20201031T063236_024053_02DB82_6073.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201031T063211_20201031T063236_024053_02DB82_6073.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201031T063211_20201031T063236_024053_02DB82_6073.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200316T165734_20200316T165759_020720_02747B_82F4.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200316T165734_20200316T165759_020720_02747B_82F4.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200316T165734_20200316T165759_020720_02747B_82F4.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200314T175311_20200314T175336_031675_03A6D2_277B.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200314T175311_20200314T175336_031675_03A6D2_277B.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200314T175311_20200314T175336_031675_03A6D2_277B.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200129T063252_20200129T063317_020028_025E45_2BE0.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200129T063252_20200129T063317_020028_025E45_2BE0.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200129T063252_20200129T063317_020028_025E45_2BE0.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200121T174432_20200121T174457_030902_038BFF_CED7.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200121T174432_20200121T174457_030902_038BFF_CED7.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200121T174432_20200121T174457_030902_038BFF_CED7.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200207T052956_20200207T053025_031142_039468_64E3.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200207T052956_20200207T053025_031142_039468_64E3.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200207T052956_20200207T053025_031142_039468_64E3.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200808T063209_20200808T063234_022828_02B539_6D9A.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200808T063209_20200808T063234_022828_02B539_6D9A.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200808T063209_20200808T063234_022828_02B539_6D9A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201113T182052_20201113T182121_024250_02E1B9_1B87.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201113T182052_20201113T182121_024250_02E1B9_1B87.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201113T182052_20201113T182121_024250_02E1B9_1B87.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200721T182757_20200721T182822_022573_02AD7D_4F47.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200721T182757_20200721T182822_022573_02AD7D_4F47.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200721T182757_20200721T182822_022573_02AD7D_4F47.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200226T055613_20200226T055638_020436_026B88_D533.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200226T055613_20200226T055638_020436_026B88_D533.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200226T055613_20200226T055638_020436_026B88_D533.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201007T182848_20201007T182913_034694_040A85_FFEE.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201007T182848_20201007T182913_034694_040A85_FFEE.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201007T182848_20201007T182913_034694_040A85_FFEE.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200708T050237_20200708T050302_022375_02A778_C74A.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200708T050237_20200708T050302_022375_02A778_C74A.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200708T050237_20200708T050302_022375_02A778_C74A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200727T164949_20200727T165014_033643_03E62C_AB7C.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200727T164949_20200727T165014_033643_03E62C_AB7C.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200727T164949_20200727T165014_033643_03E62C_AB7C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200907T054009_20200907T054034_023265_02C2E7_62EE.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200907T054009_20200907T054034_023265_02C2E7_62EE.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200907T054009_20200907T054034_023265_02C2E7_62EE.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200829T171754_20200829T171819_023141_02BF02_C8E6.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200829T171754_20200829T171819_023141_02BF02_C8E6.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200829T171754_20200829T171819_023141_02BF02_C8E6.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200227T063945_20200227T064010_020451_026BFB_0AD6.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200227T063945_20200227T064010_020451_026BFB_0AD6.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200227T063945_20200227T064010_020451_026BFB_0AD6.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200207T175311_20200207T175336_031150_0394AF_449E.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200207T175311_20200207T175336_031150_0394AF_449E.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200207T175311_20200207T175336_031150_0394AF_449E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201106T054010_20201106T054035_024140_02DE33_F727.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201106T054010_20201106T054035_024140_02DE33_F727.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201106T054010_20201106T054035_024140_02DE33_F727.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200414T174432_20200414T174457_032127_03B6BD_C3BA.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200414T174432_20200414T174457_032127_03B6BD_C3BA.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200414T174432_20200414T174457_032127_03B6BD_C3BA.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200308T074217_20200308T074237_031581_03A380_16AB.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200308T074217_20200308T074237_031581_03A380_16AB.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200308T074217_20200308T074237_031581_03A380_16AB.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200117T182839_20200117T182904_030844_0389FB_33AB.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200117T182839_20200117T182904_030844_0389FB_33AB.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200117T182839_20200117T182904_030844_0389FB_33AB.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200126T051926_20200126T051951_030967_038E4E_D901.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200126T051926_20200126T051951_030967_038E4E_D901.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200126T051926_20200126T051951_030967_038E4E_D901.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200523T075648_20200523T075717_021706_029331_7C6C.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200523T075648_20200523T075717_021706_029331_7C6C.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200523T075648_20200523T075717_021706_029331_7C6C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200812T170919_20200812T170944_022893_02B744_654C.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200812T170919_20200812T170944_022893_02B744_654C.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200812T170919_20200812T170944_022893_02B744_654C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201011T051124_20201011T051149_034744_040C52_6608.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201011T051124_20201011T051149_034744_040C52_6608.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201011T051124_20201011T051149_034744_040C52_6608.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200115T170955_20200115T171021_030814_0388F3_A85C.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200115T170955_20200115T171021_030814_0388F3_A85C.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200115T170955_20200115T171021_030814_0388F3_A85C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200606T175314_20200606T175339_032900_03CF93_A66C.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200606T175314_20200606T175339_032900_03CF93_A66C.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200606T175314_20200606T175339_032900_03CF93_A66C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200601T065012_20200601T065037_032820_03CD37_94E2.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200601T065012_20200601T065037_032820_03CD37_94E2.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200601T065012_20200601T065037_032820_03CD37_94E2.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200604T182106_20200604T182141_032871_03CEB2_970A.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200604T182106_20200604T182141_032871_03CEB2_970A.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200604T182106_20200604T182141_032871_03CEB2_970A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200302T171746_20200302T171811_020516_026E05_A99F.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200302T171746_20200302T171811_020516_026E05_A99F.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200302T171746_20200302T171811_020516_026E05_A99F.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200311T050717_20200311T050742_031623_03A4F6_5410.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200311T050717_20200311T050742_031623_03A4F6_5410.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200311T050717_20200311T050742_031623_03A4F6_5410.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200713T064919_20200713T064944_022449_02A9AF_ECFF.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200713T064919_20200713T064944_022449_02A9AF_ECFF.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200713T064919_20200713T064944_022449_02A9AF_ECFF.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200401T051836_20200401T051901_020946_027BB4_B4B9.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200401T051836_20200401T051901_020946_027BB4_B4B9.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200401T051836_20200401T051901_020946_027BB4_B4B9.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200220T064913_20200220T064938_020349_02689E_2C4E.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200220T064913_20200220T064938_020349_02689E_2C4E.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200220T064913_20200220T064938_020349_02689E_2C4E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200405T062005_20200405T062030_021005_027D7C_DB68.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200405T062005_20200405T062030_021005_027D7C_DB68.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200405T062005_20200405T062030_021005_027D7C_DB68.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200907T182800_20200907T182825_023273_02C32A_7102.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200907T182800_20200907T182825_023273_02C32A_7102.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200907T182800_20200907T182825_023273_02C32A_7102.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200310T054900_20200310T054925_031609_03A47D_EDEC.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200310T054900_20200310T054925_031609_03A47D_EDEC.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200310T054900_20200310T054925_031609_03A47D_EDEC.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200714T051348_20200714T051417_033446_03E02D_2D80.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200714T051348_20200714T051417_033446_03E02D_2D80.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200714T051348_20200714T051417_033446_03E02D_2D80.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200602T064104_20200602T064129_021851_029791_CE3E.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200602T064104_20200602T064129_021851_029791_CE3E.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200602T064104_20200602T064129_021851_029791_CE3E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200407T051926_20200407T051951_032017_03B2DF_2172.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200407T051926_20200407T051951_032017_03B2DF_2172.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200407T051926_20200407T051951_032017_03B2DF_2172.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200123T182752_20200123T182817_019948_025BC1_C8D0.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200123T182752_20200123T182817_019948_025BC1_C8D0.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200123T182752_20200123T182817_019948_025BC1_C8D0.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200501T052957_20200501T053026_032367_03BF31_9380.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200501T052957_20200501T053026_032367_03BF31_9380.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200501T052957_20200501T053026_032367_03BF31_9380.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200407T185759_20200407T185824_021042_027EAA_107A.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200407T185759_20200407T185824_021042_027EAA_107A.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200407T185759_20200407T185824_021042_027EAA_107A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200726T054816_20200726T054841_022638_02AF72_3AF8.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200726T054816_20200726T054841_022638_02AF72_3AF8.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200726T054816_20200726T054841_022638_02AF72_3AF8.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200508T052148_20200508T052217_032469_03C29A_11CF.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200508T052148_20200508T052217_032469_03C29A_11CF.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200508T052148_20200508T052217_032469_03C29A_11CF.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200606T052959_20200606T053028_032892_03CF5C_B735.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200606T052959_20200606T053028_032892_03CF5C_B735.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200606T052959_20200606T053028_032892_03CF5C_B735.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200304T064044_20200304T064109_031522_03A196_FB77.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200304T064044_20200304T064109_031522_03A196_FB77.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200304T064044_20200304T064109_031522_03A196_FB77.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200719T051120_20200719T051145_033519_03E25A_F350.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200719T051120_20200719T051145_033519_03E25A_F350.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200719T051120_20200719T051145_033519_03E25A_F350.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200807T051349_20200807T051418_033796_03EB08_246B.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200807T051349_20200807T051418_033796_03EB08_246B.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200807T051349_20200807T051418_033796_03EB08_246B.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200613T174435_20200613T174500_033002_03D297_6D0D.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200613T174435_20200613T174500_033002_03D297_6D0D.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200613T174435_20200613T174500_033002_03D297_6D0D.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200221T183536_20200221T183601_020371_02695B_B3CD.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200221T183536_20200221T183601_020371_02695B_B3CD.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200221T183536_20200221T183601_020371_02695B_B3CD.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200421T051412_20200421T051437_032221_03BA16_FC53.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200421T051412_20200421T051437_032221_03BA16_FC53.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200421T051412_20200421T051437_032221_03BA16_FC53.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200420T055645_20200420T055710_032207_03B994_B068.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200420T055645_20200420T055710_032207_03B994_B068.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200420T055645_20200420T055710_032207_03B994_B068.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201017T051042_20201017T051107_023848_02D511_8902.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201017T051042_20201017T051107_023848_02D511_8902.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201017T051042_20201017T051107_023848_02D511_8902.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# ...
# Product name: S1A_IW_GRDH_1SDV_20201012T165827_20201012T165852_034766_040D08_5C2E.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201012T165827_20201012T165852_034766_040D08_5C2E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200511T062442_20200511T062507_021530_028E04_D86B.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200511T062442_20200511T062507_021530_028E04_D86B.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200511T062442_20200511T062507_021530_028E04_D86B.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200302T175310_20200302T175335_031500_03A0BF_549A.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200302T175310_20200302T175335_031500_03A0BF_549A.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200302T175310_20200302T175335_031500_03A0BF_549A.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200408T051025_20200408T051050_021048_027ED5_767D.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200408T051025_20200408T051050_021048_027ED5_767D.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200408T051025_20200408T051050_021048_027ED5_767D.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200829T060415_20200829T060440_023134_02BECB_2A30.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200829T060415_20200829T060440_023134_02BECB_2A30.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200829T060415_20200829T060440_023134_02BECB_2A30.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200829T185857_20200829T185930_023142_02BF09_E6B7.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200829T185857_20200829T185930_023142_02BF09_E6B7.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200829T185857_20200829T185930_023142_02BF09_E6B7.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200323T063205_20200323T063230_031799_03AB2B_C194.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200323T063205_20200323T063230_031799_03AB2B_C194.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200323T063205_20200323T063230_031799_03AB2B_C194.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200916T074132_20200916T074201_034381_03FF81_AD1C.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200916T074132_20200916T074201_034381_03FF81_AD1C.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200916T074132_20200916T074201_034381_03FF81_AD1C.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201004T060416_20201004T060441_023659_02CF3D_6A47.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201004T060416_20201004T060441_023659_02CF3D_6A47.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201004T060416_20201004T060441_023659_02CF3D_6A47.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200817T051934_20200817T051959_033942_03F017_3D88.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200817T051934_20200817T051959_033942_03F017_3D88.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200817T051934_20200817T051959_033942_03F017_3D88.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200608T165738_20200608T165803_021945_029A5B_AC32.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200608T165738_20200608T165803_021945_029A5B_AC32.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200608T165738_20200608T165803_021945_029A5B_AC32.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200128T051343_20200128T051412_030996_038F5F_B1EB.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200128T051343_20200128T051412_030996_038F5F_B1EB.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200128T051343_20200128T051412_030996_038F5F_B1EB.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200806T051039_20200806T051104_022798_02B446_EFCC.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200806T051039_20200806T051104_022798_02B446_EFCC.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200806T051039_20200806T051104_022798_02B446_EFCC.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200426T055549_20200426T055614_021311_02873C_2183.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200426T055549_20200426T055614_021311_02873C_2183.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200426T055549_20200426T055614_021311_02873C_2183.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200221T064109_20200221T064134_031347_039B86_B9F3.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200221T064109_20200221T064134_031347_039B86_B9F3.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200221T064109_20200221T064134_031347_039B86_B9F3.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200924T051421_20200924T051446_034496_0403A4_B472.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200924T051421_20200924T051446_034496_0403A4_B472.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200924T051421_20200924T051446_034496_0403A4_B472.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200625T055553_20200625T055618_022186_02A1B9_8E4E.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200625T055553_20200625T055618_022186_02A1B9_8E4E.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200625T055553_20200625T055618_022186_02A1B9_8E4E.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200619T051036_20200619T051101_022098_029EF7_C2D8.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200619T051036_20200619T051101_022098_029EF7_C2D8.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200619T051036_20200619T051101_022098_029EF7_C2D8.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200525T175314_20200525T175339_032725_03CA69_250F.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200525T175314_20200525T175339_032725_03CA69_250F.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200525T175314_20200525T175339_032725_03CA69_250F.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200511T182105_20200511T182140_032521_03C436_DB7B.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200511T182105_20200511T182140_032521_03C436_DB7B.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200511T182105_20200511T182140_032521_03C436_DB7B.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200316T064134_20200316T064159_031697_03A7A5_CCE3.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200316T064134_20200316T064159_031697_03A7A5_CCE3.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200316T064134_20200316T064159_031697_03A7A5_CCE3.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200913T063146_20200913T063211_023353_02C5A2_DF75.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200913T063146_20200913T063211_023353_02C5A2_DF75.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200913T063146_20200913T063211_023353_02C5A2_DF75.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200601T055616_20200601T055641_021836_029727_F743.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200601T055616_20200601T055641_021836_029727_F743.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200601T055616_20200601T055641_021836_029727_F743.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200911T055653_20200911T055718_034307_03FCED_EFF4.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200911T055653_20200911T055718_034307_03FCED_EFF4.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200911T055653_20200911T055718_034307_03FCED_EFF4.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200522T050605_20200522T050630_032673_03C8C7_2055.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200522T050605_20200522T050630_032673_03C8C7_2055.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200522T050605_20200522T050630_032673_03C8C7_2055.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200507T051846_20200507T051911_021471_028C4A_E168.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200507T051846_20200507T051911_021471_028C4A_E168.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200507T051846_20200507T051911_021471_028C4A_E168.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200726T064140_20200726T064205_033622_03E596_B121.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200726T064140_20200726T064205_033622_03E596_B121.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200726T064140_20200726T064205_033622_03E596_B121.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200321T174431_20200321T174456_031777_03AA65_8AB1.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200321T174431_20200321T174456_031777_03AA65_8AB1.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200321T174431_20200321T174456_031777_03AA65_8AB1.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20201026T062014_20201026T062039_023980_02D93F_309F.SAFE
# Product name: S1B_IW_GRDH_1SDV_20201026T062014_20201026T062039_023980_02D93F_309F.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20201026T062014_20201026T062039_023980_02D93F_309F.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200515T051413_20200515T051438_032571_03C5C6_E567.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200515T051413_20200515T051438_032571_03C5C6_E567.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200515T051413_20200515T051438_032571_03C5C6_E567.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20201110T185132_20201110T185200_035190_041BCB_0D41.SAFE
# Product name: S1A_IW_GRDH_1SDV_20201110T185132_20201110T185200_035190_041BCB_0D41.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20201110T185132_20201110T185200_035190_041BCB_0D41.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# Error finding corresponding L0 product: a must be greater than 0 unless no samples are taken
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200807T050321_20200807T050346_033796_03EB07_3170.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200807T050321_20200807T050346_033796_03EB07_3170.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200807T050321_20200807T050346_033796_03EB07_3170.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1B_IW_GRDH_1SDV_20200722T062446_20200722T062511_022580_02ADAC_0373.SAFE
# Product name: S1B_IW_GRDH_1SDV_20200722T062446_20200722T062511_022580_02ADAC_0373.SAFE
# Searching for product with exact name: S1B_IW_GRDH_1SDV_20200722T062446_20200722T062511_022580_02ADAC_0373.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected
# Using product: /Data_large/marine/PythonProjects/SAR/sarpyx/data/xview3/GRD/S1A_IW_GRDH_1SDV_20200614T165822_20200614T165847_033016_03D2FD_6765.SAFE
# Product name: S1A_IW_GRDH_1SDV_20200614T165822_20200614T165847_033016_03D2FD_6765.SAFE
# Searching for product with exact name: S1A_IW_GRDH_1SDV_20200614T165822_20200614T165847_033016_03D2FD_6765.SAFE
#
# WKT polygon normalized: Whitespace and formatting corrected
# WKT polygon normalized: Whitespace and formatting corrected

# %%
df

# %%
[{'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'timeliness', 'Value': 'Fast-24h', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'coordinates', 'Value': '45.460442,-12.755283 45.857189,-9.512984 44.240639,-9.156878 43.844185,-12.306799 45.460442,-12.755283', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.IntegerAttribute', 'Name': 'orbitNumber', 'Value': 35117, 'ValueType': 'Integer'}, {'@odata.type': '#OData.CSC.IntegerAttribute', 'Name': 'sliceNumber', 'Value': 11, 'ValueType': 'Integer'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'productClass', 'Value': 'S', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'orbitDirection', 'Value': 'ASCENDING', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'operationalMode', 'Value': 'IW', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'processingLevel', 'Value': 'LEVEL1', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'swathIdentifier', 'Value': 'IW1 IW2 IW3', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'platformShortName', 'Value': 'SENTINEL-1', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'instrumentShortName', 'Value': 'SAR', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.IntegerAttribute', 'Name': 'relativeOrbitNumber', 'Value': 45, 'ValueType': 'Integer'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'polarisationChannels', 'Value': 'VV&VH', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'platformSerialIdentifier', 'Value': 'A', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.StringAttribute', 'Name': 'productType', 'Value': 'IW_SLC__1S', 'ValueType': 'String'}, {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute', 'Name': 'beginningDateTime', 'Value': '2020-11-05T18:37:14.092000Z', 'ValueType': 'DateTimeOffset'}, {'@odata.type': '#OData.CSC.DateTimeOffsetAttribute', 'Name': 'endingDateTime', 'Value': '2020-11-05T18:37:41.052000Z', 'ValueType': 'DateTimeOffset'}]

# %%
print(len(L1_L0_pairs))
